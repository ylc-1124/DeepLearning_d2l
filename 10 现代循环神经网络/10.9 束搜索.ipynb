# %% [markdown]
# ## 贪心搜索
# 在之前Seq2Seq中预测词元时候，每次选择当前概率最大的词元，根据贪心的思想可知，每次选择当前最优未必是整体最优
# ![image.png](attachment:image.png)
# 第二张图，对第二个词元预测时，未选择最大概率，因此导致后续的预测发生变化，最终发现整个序列的概率更高一些

# %% [markdown]
# ## 穷举搜索
# 贪心最快但未必最优，穷举能得到最优解但是算不动，因此引出了束搜索
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 束搜索
# 每次可以在kn中候选中保存k个（贪心搜索就是k=1的情况）
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 时间复杂度
# ![image.png](attachment:image.png)
# ### 计算得分
# 由于长句子出现的概率小于短句子，因此模型会优先选择短句子<br>
# 使用1/L^alpha给长句子奖励，增加长句子被选择的概率
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 总结
# ![image.png](attachment:image.png)
